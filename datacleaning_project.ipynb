# %%
import pandas as pd

# %%
df = pd.read_csv("Independent_Medical_Reviews.csv")

# %%
df.head()
# Out:
#   Reference ID  Report Year      Diagnosis Category Diagnosis Sub Category  \
# 0   MN16-22639         2016              Infectious              Hepatitis
# 1   MN16-22638         2016                  Mental        Eating Disorder
# 2   MN16-22637         2016         Autism Spectrum         Autism-PDD-NOS
# 3   EI16-22636         2016  Prevention/Good Health                    NaN
# 4    EI06-5319         2006     Cardiac/Circulatory                    NaN
#
#                           Treatment Category  \
# 0                Pharmacy/Prescription Drugs
# 1                    Mental Health Treatment
# 2                   Autism Related Treatment
# 3  Diagnostic Imaging, Screening and Testing
# 4                            Cardio Vascular
#
#                      Treatment Sub Category  \
# 0                               Anti-virals
# 1  Residential Treatment Center - Admission
# 2                            Speech Therapy
# 3                               Mammography
# ...

# %%
df.tail(3)
# Out:
#       Reference ID  Report Year           Diagnosis Category  \
# 19242       MN01-5         2001  Orthopedic/ Musculoskeletal
# 19243       MN01-4         2001  Orthopedic/ Musculoskeletal
# 19244       EI01-3         2001                       Cancer
#
#       Diagnosis Sub Category              Treatment Category  \
# 19242                  Other                      Orthopedic
# 19243              Back Pain  Reconstructive/Plastic Surgery
# 19244            Lung Cancer                Cancer Treatment
#
#          Treatment Sub Category                       Determination  \
# 19242               Arthroscopy      Upheld Decision of Health Plan
# 19243          Breast Reduction  Overturned Decision of Health Plan
# 19244  Clinical Trial (Phase 1)      Upheld Decision of Health Plan
#
#                                Type Age Range Patient Gender  \
# 19242             Medical Necessity       NaN            NaN
# 19243             Medical Necessity       NaN            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19245 entries, 0 to 19244
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Reference ID            19245 non-null  object
#  1   Report Year             19245 non-null  int64
#  2   Diagnosis Category      19186 non-null  object
#  3   Diagnosis Sub Category  17341 non-null  object
#  4   Treatment Category      18795 non-null  object
#  5   Treatment Sub Category  17977 non-null  object
#  6   Determination           19245 non-null  object
#  7   Type                    19245 non-null  object
#  8   Age Range               18035 non-null  object
#  9   Patient Gender          18035 non-null  object
#  10  Findings                19225 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#         Report Year
# count  19245.000000
# mean    2009.662977
# std        4.272045
# min     2001.000000
# 25%     2007.000000
# 50%     2010.000000
# 75%     2014.000000
# max     2016.000000

# %%
df.isnull().sum()
# Out:
# Reference ID                 0
# Report Year                  0
# Diagnosis Category          59
# Diagnosis Sub Category    1904
# Treatment Category         450
# Treatment Sub Category    1268
# Determination                0
# Type                         0
# Age Range                 1210
# Patient Gender            1210
# Findings                    20
# dtype: int64

# %%
categorical_cols = ['Diagnosis Category', 'Diagnosis Sub Category', 'Treatment Category', 'Treatment Sub Category', 'Determination',
                    'Type', 'Age Range', 'Patient Gender', '']

# %%
df['Diagnosis Sub Category'].fillna('Unknown', inplace=True)
df['Treatment Sub Category'].fillna('Unknown', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\the_SocialMediaBabe\Desktop\KidsSafe\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Diagnosis Sub Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
# Convert all column names and data to lowercase and strip whitespaces
df.columns = [col.lower().strip() for col in df.columns]
df = df.applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)

# %%
df['Findings'].fillna

# %%
df.dropna()
df.dropna(axis=1)
# Out:
#       reference id  report year                       determination  \
# 0       mn16-22639         2016  overturned decision of health plan
# 1       mn16-22638         2016      upheld decision of health plan
# 2       mn16-22637         2016      upheld decision of health plan
# 3       ei16-22636         2016  overturned decision of health plan
# 4        ei06-5319         2006      upheld decision of health plan
# ...            ...          ...                                 ...
# 19240       mn01-7         2001  overturned decision of health plan
# 19241       mn01-6         2001      upheld decision of health plan
# 19242       mn01-5         2001      upheld decision of health plan
# 19243       mn01-4         2001  overturned decision of health plan
# 19244       ei01-3         2001      upheld decision of health plan
#
#                                type
# 0                 medical necessity
# 1                 medical necessity
# 2                 medical necessity
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.columns)
# Out:
# Index(['reference id', 'report year', 'diagnosis category',
#        'diagnosis sub category', 'treatment category',
#        'treatment sub category', 'determination', 'type', 'age range',
#        'patient gender', 'findings'],
#       dtype='object')

# %%
df.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.fillna()
#
# File c:\Users\the_SocialMediaBabe\Desktop\KidsSafe\venv\Lib\site-packages\pandas\core\generic.py:7312, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7305         if ctr <= ref_count:
#    7306             warnings.warn(
#    7307                 _chained_assignment_warning_method_msg,
#    7308                 FutureWarning,
#    7309                 stacklevel=2,
#    7310             )
# -> 7312 value, method = validate_fillna_kwargs(value, method)
#    7313 if method is not None:
#    7314     warnings.warn(
#    7315         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7316         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)   7319         stacklevel=find_stack_level(),
#    7320     )
#
# ...
