# %% [markdown]
# A function for calculating the perimeter and area of a rectangle

# %%
def calculate_rectangle_properties(length, width):
    perimeter = int(2 * (length + width))
    area = float(length * width)
    return perimeter, area
    length = 10
    width = 5
    
    area, perimeter = calculate_rectangle_properties(length, width)
    print(f"the rectangle has an area of: {area} square units and a perimeter of: {perimeter} units")

    
    #return perimeter, area
